# %% [markdown]
# # SQL 生成測試

# %% [markdown]
# ## 載入套件

# %%
import os
import openai

# %% [markdown]
# ## 產生SQL指令

# %%
prompt = '''
CREATE TABLE "Orders" 
(
  "Id" INTEGER PRIMARY KEY, 
  "CustomerId" VARCHAR(8000) NULL, 
  "EmployeesId" INTEGER NOT NULL, 
  "orderdate" VARCHAR(8000) NULL, 
  "RequiredDate" VARCHAR(8000) NULL, 
  "ShippedDate" VARCHAR(8000) NULL, 
  "ShipVia" INTEGER NULL, 
  "Freight" DECIMAL NOT NULL, 
  "ShipName" VARCHAR(8000) NULL, 
  "ShipAddress" VARCHAR(8000) NULL, 
  "ShipCity" VARCHAR(8000) NULL, 
  "ShipRegion" VARCHAR(8000) NULL, 
  "ShipPostalCode" VARCHAR(8000) NULL, 
  "ShipCountry" VARCHAR(8000) NULL 
);

CREATE TABLE "Customers" 
(
  "Id" VARCHAR(8000) PRIMARY KEY, 
  "CompanyName" VARCHAR(8000) NULL, 
  "ContactName" VARCHAR(8000) NULL, 
  "ContactTitle" VARCHAR(8000) NULL, 
  "Address" VARCHAR(8000) NULL, 
  "City" VARCHAR(8000) NULL, 
  "Region" VARCHAR(8000) NULL, 
  "PostalCode" VARCHAR(8000) NULL, 
  "Country" VARCHAR(8000) NULL, 
  "Phone" VARCHAR(8000) NULL, 
  "Fax" VARCHAR(8000) NULL 
);
-- find the customer name of order id = 10251
'''
messages=[
    {"role": "system", "content": "you are a Database expert."},
    {"role": "user", "content": prompt}
]
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=messages,
)
print(response.choices[0].message.content)
# Out:
# To find the customer name associated with order id 10251, you can use the following SQL query:
#
# ```
# SELECT Customers.CompanyName
# FROM Orders
# INNER JOIN Customers
# ON Orders.CustomerId = Customers.Id
# WHERE Orders.Id = 10251
# ```
#
# This query joins the Orders and Customers tables using the CustomerId column in the Orders table and the Id column in the Customers table. Then it limits the results to only the row where the Order Id is equal to 10251. Finally, it selects the CompanyName column from the Customers table, which will give you the customer name for that order.

# %% [markdown]
# ## 截取SQL指令

# %%
print(response.choices[0].message.content.split('```')[1])
# Out:
# SELECT Customers.CompanyName
# FROM Orders
# INNER JOIN Customers
# ON Orders.CustomerId = Customers.Id
# WHERE Orders.Id = 10251

# %% [markdown]
# ## 執行SQL

# %%
from sqlalchemy import create_engine
from sqlalchemy import text

engine = create_engine("sqlite:///data/Northwind.db", echo=False)
sql = response.choices[0].message.content.split('```')[1]
results = engine.execute(text(sql))
  
# View the records
for record in results:
    print(record[0])
# Out:
# Victuailles en stock

# %% [markdown]
# # 查詢多筆資料

# %% [markdown]
# ## 產生SQL指令

# %%
prompt = '''
CREATE TABLE "Orders" 
(
  "Id" INTEGER PRIMARY KEY, 
  "CustomerId" VARCHAR(8000) NULL, 
  "EmployeesId" INTEGER NOT NULL, 
  "orderdate" VARCHAR(8000) NULL, 
  "RequiredDate" VARCHAR(8000) NULL, 
  "ShippedDate" VARCHAR(8000) NULL, 
  "ShipVia" INTEGER NULL, 
  "Freight" DECIMAL NOT NULL, 
  "ShipName" VARCHAR(8000) NULL, 
  "ShipAddress" VARCHAR(8000) NULL, 
  "ShipCity" VARCHAR(8000) NULL, 
  "ShipRegion" VARCHAR(8000) NULL, 
  "ShipPostalCode" VARCHAR(8000) NULL, 
  "ShipCountry" VARCHAR(8000) NULL 
);

CREATE TABLE "Customers" 
(
  "Id" VARCHAR(8000) PRIMARY KEY, 
  "CompanyName" VARCHAR(8000) NULL, 
  "ContactName" VARCHAR(8000) NULL, 
  "ContactTitle" VARCHAR(8000) NULL, 
  "Address" VARCHAR(8000) NULL, 
  "City" VARCHAR(8000) NULL, 
  "Region" VARCHAR(8000) NULL, 
  "PostalCode" VARCHAR(8000) NULL, 
  "Country" VARCHAR(8000) NULL, 
  "Phone" VARCHAR(8000) NULL, 
  "Fax" VARCHAR(8000) NULL 
);
-- find all orders for the customer name = "Alfreds Futterkiste"
'''
messages=[
    {"role": "system", "content": "you are a Database expert."},
    {"role": "user", "content": prompt}
]
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=messages,
)
print(response.choices[0].message.content)
# Out:
# To find all orders for the customer name "Alfreds Futterkiste", you need to join the "Orders" and "Customers" tables and filter the results by the customer name. You can use the following SQL query:
#
# SELECT *
# FROM Orders o
# INNER JOIN Customers c ON o.CustomerId = c.Id
# WHERE c.CompanyName = 'Alfreds Futterkiste';
#
# This query will return all orders that belong to the customer with the company name "Alfreds Futterkiste".

# %% [markdown]
# ## 截取SQL指令

# %%
if '```' in response.choices[0].message.content:
    sql = response.choices[0].message.content.split('```')[1]
else:
    sql = response.choices[0].message.content.split('\n\n')[1]

print(sql)
# Out:
# SELECT *
# FROM Orders o
# INNER JOIN Customers c ON o.CustomerId = c.Id
# WHERE c.CompanyName = 'Alfreds Futterkiste';

# %% [markdown]
# ## 執行SQL

# %%
from sqlalchemy import create_engine
from sqlalchemy import text
import pandas as pd

engine = create_engine("sqlite:///data/Northwind.db", echo=False)
df = pd.read_sql(sql, engine)
df
# Out:
#       Id CustomerId  EmployeesId   orderdate RequiredDate ShippedDate  \
# 0  10643      ALFKI            6  2013-08-25   2013-09-22  2013-09-02
# 1  10692      ALFKI            4  2013-10-03   2013-10-31  2013-10-13
# 2  10702      ALFKI            4  2013-10-13   2013-11-24  2013-10-21
# 3  10835      ALFKI            1  2014-01-15   2014-02-12  2014-01-21
# 4  10952      ALFKI            1  2014-03-16   2014-04-27  2014-03-24
# 5  11011      ALFKI            3  2014-04-09   2014-05-07  2014-04-13
#
#    ShipVia  Freight              ShipName    ShipAddress  ...  \
# 0        1    29.46   Alfreds Futterkiste  Obere Str. 57  ...
# 1        2    61.02  Alfred's Futterkiste  Obere Str. 57  ...
# 2        1    23.94  Alfred's Futterkiste  Obere Str. 57  ...
# 3        3    69.53  Alfred's Futterkiste  Obere Str. 57  ...
# 4        1    40.42  Alfred's Futterkiste  Obere Str. 57  ...
# 5        1     1.21  Alfred's Futterkiste  Obere Str. 57  ...
#
#            CompanyName   ContactName          ContactTitle        Address  \
# 0  Alfreds Futterkiste  Maria Anders  Sales Representative  Obere Str. 57
# 1  Alfreds Futterkiste  Maria Anders  Sales Representative  Obere Str. 57
# 2  Alfreds Futterkiste  Maria Anders  Sales Representative  Obere Str. 57
# 3  Alfreds Futterkiste  Maria Anders  Sales Representative  Obere Str. 57
# 4  Alfreds Futterkiste  Maria Anders  Sales Representative  Obere Str. 57
# 5  Alfreds Futterkiste  Maria Anders  Sales Representative  Obere Str. 57
#
#      City          Region PostalCode  Country        Phone          Fax
# 0  Berlin  Western Europe      12209  Germany  030-0074321  030-0076545
# 1  Berlin  Western Europe      12209  Germany  030-0074321  030-0076545
# 2  Berlin  Western Europe      12209  Germany  030-0074321  030-0076545
# 3  Berlin  Western Europe      12209  Germany  030-0074321  030-0076545
# 4  Berlin  Western Europe      12209  Germany  030-0074321  030-0076545
# 5  Berlin  Western Europe      12209  Germany  030-0074321  030-0076545
#
# [6 rows x 25 columns]

# %%
from sqlalchemy import create_engine
from sqlalchemy import text
import pandas as pd

engine = create_engine("sqlite:///data/Northwind.db", echo=False)
sql = "select * from sqlite_master WHERE type='table'"
df = pd.read_sql(sql, engine)
df
# Out:
#      type                  name              tbl_name  rootpage  \
# 0   table             Employees             Employees         2
# 1   table             Customers             Customers         4
# 2   table              Shippers              Shippers        10
# 3   table             Suppliers             Suppliers        11
# 4   table              Products              Products        43
# 5   table          OrderDetails          OrderDetails        46
# 6   table  CustomerCustomerDemo  CustomerCustomerDemo        75
# 7   table   CustomerDemographic   CustomerDemographic        77
# 8   table               Regions               Regions        79
# 9   table           Territories           Territories        80
# 10  table   EmployeeTerritories   EmployeeTerritories        84
# 11  table            Categories            Categories         3
# 12  table                Orders                Orders        14
#
#                                                   sql
# 0   CREATE TABLE "Employees" \r\n(\r\n  "Id" INTEG...
# 1   CREATE TABLE "Customers" \r\n(\r\n  "Id" VARCH...
# 2   CREATE TABLE "Shippers" \r\n(\r\n  "Id" INTEGE...
# 3   CREATE TABLE "Suppliers" \r\n(\r\n  "Id" INTEG...
# 4   CREATE TABLE "Products" \r\n(\r\n  "Id" INTEGE...
# 5   CREATE TABLE "OrderDetails" \r\n(\r\n  "Id" VA...
# 6   CREATE TABLE "CustomerCustomerDemo" \r\n(\r\n ...
# 7   CREATE TABLE "CustomerDemographic" \r\n(\r\n  ...
# 8   CREATE TABLE "Regions" \r\n(\r\n  "Id" INTEGER...
# 9   CREATE TABLE "Territories" \r\n(\r\n  "Id" VAR...
# 10  CREATE TABLE "EmployeeTerritories" \r\n(\r\n  ...
# 11  CREATE TABLE "Categories" \r\n(\r\n  "Id" INTE...
# 12  CREATE TABLE "Orders" \r\n(\r\n  "Id" INTEGER ...
